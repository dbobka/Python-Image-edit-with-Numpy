# %% [markdown]
# # Image edit using Numpy

# %% [markdown]
# Data Source: Central Park photo

# %% [markdown]
# # Loading the libraries: numpy, scipy, matplotlib

# %%
import numpy as np

# %% [markdown]
# # Creating a numpy array from an image file:

# %% [markdown]
# Choose a Central Park image file as an ndarray and display its type

# %%
from skimage import data

photo_data = misc.imread('./image/Central_Park.jpg')

type(photo_data)
# Out:
# C:\Users\dbobk\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# numpy.ndarray

# %% [markdown]
# Show the image

# %%
plt.figure(figsize=(15,15))
plt.imshow(photo_data)

# %%
photo_data.shape

#print(photo_data)
# Out:
# (720, 960, 3)

# %% [markdown]
# 720 is the height, 960 is the width, and it has 3 layers for RGB

# %% [markdown]
# # Masking the Image

# %% [markdown]
# Add a circular mask

# %%
total_rows, total_cols, total_layers = photo_data.shape
#print("photo_data = ", photo_data.shape)

X, Y = np.ogrid[:total_rows, :total_cols]
#print("X = ", X.shape, " and Y = ", Y.shape)

# %%
center_row, center_col = total_rows / 2, total_cols / 2
#print("center_row = ", center_row, "AND center_col = ", center_col)
#print(X - center_row)
#print(Y - center_col)
dist_from_center = (X - center_row)**2 + (Y - center_col)**2
#print(dist_from_center)
radius = (total_rows / 2)**2
#print("Radius = ", radius)
circular_mask = (dist_from_center > radius)

# %%
photo_data = misc.imread('./image/Central_Park.jpg')
photo_data[circular_mask] = 0
plt.figure(figsize=(15,15))
plt.imshow(photo_data)
# Out:
# C:\Users\dbobk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
